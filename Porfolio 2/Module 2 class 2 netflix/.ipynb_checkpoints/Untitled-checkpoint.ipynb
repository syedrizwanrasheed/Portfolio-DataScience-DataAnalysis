# %%
import pandas as pd

# %%
netflix = pd.read_csv("netflix.csv" , encoding = 'latin-1')

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4001 entries, 0 to 4000
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          3934 non-null   object
#  1   title         4001 non-null   object
#  2   date_added    4001 non-null   object
#  3   release_year  4001 non-null   object
#  4   rating        4001 non-null   object
#  5   listed_in     4001 non-null   object
# dtypes: object(6)
# memory usage: 187.7+ KB

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4001 entries, 0 to 4000
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          3934 non-null   object
#  1   title         4001 non-null   object
#  2   date_added    4001 non-null   object
#  3   release_year  4001 non-null   object
#  4   rating        4001 non-null   object
#  5   listed_in     4001 non-null   object
# dtypes: object(6)
# memory usage: 187.7+ KB

# %%
netflix.head()
# Out:
#       type                                 title date_added release_year  \
# 0    Movie              **Dick Johnson Is Dead**  9/25/2021        2020)
# 1  TV Show                         **Ganglands**  9/24/2021        2021C
# 2  TV Show                     **Midnight Mass**  9/24/2021        2021c
# 3    Movie  **Confessions of an Invisible Girl**  9/22/2021         2021
# 4    Movie                           **Sankofa**  9/24/2021        1993S
#
#     rating                                          listed_in
# 0  ,?PG-13                                      Documentaries
# 1  ,?TV-MA  Crime TV Shows, International TV Shows, TV Act...
# 2  ,?TV-MA                 TV Dramas, TV Horror, TV Mysteries
# 3  ,?TV-PG                 Children & Family Movies, Comedies
# 4  ,?TV-MA   Dramas, Independent Movies, International Movies

# %%
netflix["type"].value_counts()
# Out:
# Movie      3453
# TV Show     481
# Name: type, dtype: int64

# %%
netflix["title"].value_counts()
# Out:
# **09-Feb**                                   2
# **Dick Johnson Is Dead**                     1
# **Los Tigres del Norte at Folsom Prison**    1
# **Jeff Dunham: Beside Himself**              1
# **Manmadhudu 2**                             1
#                                             ..
# **Bobby Jasoos**                             1
# **Tarung Sarung**                            1
# **Too Handsome to Handle**                   1
# **SanPa: Sins of the Savior**                1
# **The Butterfly's Dream**                    1
# Name: title, Length: 4000, dtype: int64

# %%
netflix["title"] = netflix["title"].str.strip('*')

# %%
netflix
# Out:
#          type                             title  date_added release_year  \
# 0       Movie              Dick Johnson Is Dead   9/25/2021        2020)
# 1     TV Show                         Ganglands   9/24/2021        2021C
# 2     TV Show                     Midnight Mass   9/24/2021        2021c
# 3       Movie  Confessions of an Invisible Girl   9/22/2021         2021
# 4       Movie                           Sankofa   9/24/2021        1993S
# ...       ...                               ...         ...          ...
# 3996    Movie                        One 2 Ka 4   3/15/2017        2001S
# 3997    Movie     Jim Norton: Mouthful of Shame   3/14/2017         2017
# 3998    Movie                        100 Meters  03/10/2017        2016s
# 3999    Movie                     Burning Sands  03/10/2017        2017s
# 4000    Movie             The Butterfly's Dream  03/10/2017         2013
#
#        rating                                          listed_in
# ...

# %%
netflix['date_added'].value_counts()
# Out:
# 10/01/2018    59
# 07/01/2021    57
# 09/01/2021    53
# 11/01/2018    44
# 06/02/2021    43
#               ..
# 1/18/2021      1
# 04/08/2019     1
# 04/07/2019     1
# 01/03/2021     1
# 9/25/2021      1
# Name: date_added, Length: 1115, dtype: int64

# %%
netflix['release_year'].value_counts()
# Out:
# 2020     149
# 2019     145
# 2018     139
# 2017     104
# 2019s     87
#         ...
# 1988C      1
# 1989c      1
# 1984(      1
# 1995C      1
# 1975c      1
# Name: release_year, Length: 266, dtype: int64

# %%
netflix['release_year'] = netflix['release_year'].str.strip("C").str.strip("s").str.strip("c").str.strip("(").str.strip(")").str.strip("S")

# %%
netflix
# Out:
#          type                             title  date_added release_year  \
# 0       Movie              Dick Johnson Is Dead   9/25/2021         2020
# 1     TV Show                         Ganglands   9/24/2021         2021
# 2     TV Show                     Midnight Mass   9/24/2021         2021
# 3       Movie  Confessions of an Invisible Girl   9/22/2021         2021
# 4       Movie                           Sankofa   9/24/2021         1993
# ...       ...                               ...         ...          ...
# 3996    Movie                        One 2 Ka 4   3/15/2017         2001
# 3997    Movie     Jim Norton: Mouthful of Shame   3/14/2017         2017
# 3998    Movie                        100 Meters  03/10/2017         2016
# 3999    Movie                     Burning Sands  03/10/2017         2017
# 4000    Movie             The Butterfly's Dream  03/10/2017         2013
#
#        rating                                          listed_in
# ...

# %%
netflix['rating'].value_counts()
# Out:
# ,?TV-MA    1561
# ,?TV-14    1041
# ,?R         369
# ,?TV-PG     340
# ,?PG-13     226
# ,?PG        124
# ,?TV-Y7     120
# ,?TV-Y      117
# ,?TV-G       89
# ,?G          13
# ,?NC-17       1
# Name: rating, dtype: int64

# %%
netflix['rating'].str.strip(',').str.strip('?')
# Out:
# 0       PG-13
# 1       TV-MA
# 2       TV-MA
# 3       TV-PG
# 4       TV-MA
#         ...
# 3996    TV-14
# 3997    TV-MA
# 3998    TV-MA
# 3999    TV-MA
# 4000    TV-PG
# Name: rating, Length: 4001, dtype: object

# %%
netflix['rating'] = netflix['rating'].str.strip(',').str.strip('?')

# %%
netflix
# Out:
#          type                             title  date_added release_year  \
# 0       Movie              Dick Johnson Is Dead   9/25/2021         2020
# 1     TV Show                         Ganglands   9/24/2021         2021
# 2     TV Show                     Midnight Mass   9/24/2021         2021
# 3       Movie  Confessions of an Invisible Girl   9/22/2021         2021
# 4       Movie                           Sankofa   9/24/2021         1993
# ...       ...                               ...         ...          ...
# 3996    Movie                        One 2 Ka 4   3/15/2017         2001
# 3997    Movie     Jim Norton: Mouthful of Shame   3/14/2017         2017
# 3998    Movie                        100 Meters  03/10/2017         2016
# 3999    Movie                     Burning Sands  03/10/2017         2017
# 4000    Movie             The Butterfly's Dream  03/10/2017         2013
#
#      rating                                          listed_in
# ...

# %%
netflix['listed_in'].value_counts()
# Out:
# Stand-Up Comedy                                                    249
# Dramas, International Movies                                       224
# Comedies, Dramas, International Movies                             209
# Dramas, Independent Movies, International Movies                   148
# Documentaries                                                      142
#                                                                   ...
# Comedies, Romantic Movies, Sports Movies                             1
# Anime Series, International TV Shows, Spanish-Language TV Shows      1
# British TV Shows, Romantic TV Shows, TV Dramas                       1
# International TV Shows, Korean TV Shows, TV Comedies                 1
# Documentaries, Dramas, International Movies                          1
# Name: listed_in, Length: 324, dtype: int64
